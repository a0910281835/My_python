# %% [markdown]
# ## Using part of feature of boston'houses

# %%
## load_package 
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

## data_aalysis package
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import load_boston

# %%
boston_dataset = load_boston()

# %%
boston_dataset.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
## test to take the max in first coordinate 
boston_dataset.data[:,0].max()
# Out:
# 88.9762

# %%
## test to take the min in first coordinate 
m=boston_dataset.data[:,0].min()

# %%
(boston_dataset.data[:,0]-m)/(M-m)
# Out:
# array([0.00000000e+00, 2.35922539e-04, 2.35697744e-04, 2.92795719e-04,
#        7.05070075e-04, 2.64471527e-04, 9.21323037e-04, 1.55367187e-03,
#        2.30325139e-03, 1.84017333e-03, 2.45667410e-03, 1.24929920e-03,
#        9.83029313e-04, 7.00731528e-03, 7.09948131e-03, 6.98067706e-03,
#        1.17748838e-02, 8.74318365e-03, 8.95123159e-03, 8.08678173e-03,
#        1.39987825e-02, 9.50568889e-03, 1.37816304e-02, 1.10386796e-02,
#        8.36170623e-03, 9.37643166e-03, 7.48107112e-03, 1.06715891e-02,
#        8.61718595e-03, 1.11962610e-02, 1.26389965e-02, 1.51556909e-02,
#        1.55296377e-02, 1.28740198e-02, 1.80566727e-02, 6.50220052e-04,
#        1.02416683e-03, 8.29719002e-04, 1.89648452e-03, 2.39519262e-04,
#        3.06508225e-04, 1.36135960e-03, 1.51939061e-03, 1.72013270e-03,
#        1.30797074e-03, 1.85568419e-03, 2.04608571e-03, 2.50590425e-03,
#        2.78240231e-03, 2.39912654e-03, 9.26268530e-04, 4.16433067e-04,
# ...

# %%
((boston_dataset.data[:,0]-m)/(M-m)).min()
# Out:
# 0.0

# %%
## 1 way using for-loop
M=list()
for i in range(0,13):
    M.append(boston_dataset.data[:,i].max())

# %%
## 2 second way using one-listd (calculate th max)
M=np.array([boston_dataset.data[:,i].max() for i in range(0,13)])

# %%
M
# Out:
# array([ 88.9762, 100.    ,  27.74  ,   1.    ,   0.871 ,   8.78  ,
#        100.    ,  12.1265,  24.    , 711.    ,  22.    , 396.9   ,
#         37.97  ])

# %%
## (calculate the min)
m=np.array([boston_dataset.data[:,i].min() for i in range(0,13)])

# %%
m
# Out:
# array([6.3200e-03, 0.0000e+00, 4.6000e-01, 0.0000e+00, 3.8500e-01,
#        3.5610e+00, 2.9000e+00, 1.1296e+00, 1.0000e+00, 1.8700e+02,
#        1.2600e+01, 3.2000e-01, 1.7300e+00])

# %%
## nomalization for boston_dataset.data
normali=((boston_dataset.data-m)/(M-m))

# %%
boston=pd.DataFrame(normali,columns=boston_date.feature_names)

# %%
boston['MEDV']=boston_date.target

# %%
boston
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...

# %%
boston.sort_values(by="MEDV",ascending=False).index[:20]
# Out:
# Int64Index([284, 226, 370, 371, 372, 373, 187, 205, 258, 196, 167, 164, 268,
#             163, 162, 369, 263, 204, 234, 229],
#            dtype='int64')

# %%
boston.corr().round(2)
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %%
### it means 6/20 is 1 in CHAS
boston[boston["CHAS"]==1].index&boston.sort_values(by="MEDV",ascending=False).index[:20]
# Out:
# Int64Index([163, 164, 284, 370, 371, 373], dtype='int64')

# %%
# set operation
set([1,34])&set([1,3])
# Out:
# {1}

# %%
from sklearn import preprocessing

# %%
boston_dataset1 = load_boston()
boston_normalized = preprocessing.minmax_scale(boston_dataset1.data)
boston = pd.DataFrame(boston_normalized, columns=boston_dataset1.feature_names)

boston['MEDV'] = boston_dataset1.target

# %%
boston
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
# ...
