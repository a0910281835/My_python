# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_html('https://zh.wikipedia.org/wiki/%E9%87%8E%E8%8C%82%E8%8B%B1%E9%9B%84')

# %%
for i,ele in enumerate(df):
    print(i,len(ele))
# Out:
# 0 13
# 1 1
# 2 3
# 3 22
# 4 10
# 5 8
# 6 3
# 7 1
# 8 20
# 9 18
# 10 14
# 11 12
# 12 122
# 13 120
# 14 18
# 15 16
# 16 16
# 17 14
# 18 16
# 19 14
# 20 16
# 21 14
# 22 16
# 23 14
# 24 18
# 25 16
# 26 18
# 27 16
# 28 2
# 29 1

# %%
for i in df:
    print(i)
# Out:
#                                                  野茂英雄  \
# 0                                                 NaN
# 1                                                  投手
# 2                                           出生： （51歲）
# 3                                           打擊：右 投球：右
# 4                                                打擊：右
# 5                                                  首秀
# 6                                   1995年5月2日，代表洛杉磯道奇
# 7                                   生涯成績 （MLB，2008年止）
# 8                                                 勝－敗
# 9                                                 防禦率
# 10                                                 三振
# 11                                                 球队
# 12  大阪近鐵野牛 (1990-1994) 洛杉磯道奇 (1995-1998) 紐約大都會 (19...
#
#                                                野茂英雄.1
# 0                                                 NaN
# 1                                                  投手
# ...

# %%
df=df[3]

# %%
df.columns
# Out:
# Index(['年度', '球團', '出場', '先發', '完投', '完封', '無四球', '勝利', '敗戰', '救援', '中繼點',
#        '勝率', '打者', '投球局數', '被安打', '被全壘打', '保送', '敬遠', '觸身球', '三振數', '暴投', '犯規',
#        '失分', '自責分', '防禦率', 'WHIP'],
#       dtype='object')

# %%
df
# Out:
#          年度       球團   出場   先發  完投  完封  無四球   勝利   敗戰  救援  ...    保送    敬遠  \
# 0      1990       近鐵   29   27  21   2  NaN   18    8   0  ...   109   NaN
# 1      1991       近鐵   31   29  22   4  NaN   17   11   1  ...   128   NaN
# 2      1992       近鐵   30   29  17   5  NaN   18    8   0  ...   117   NaN
# 3      1993       近鐵   32   32  14   2  NaN   17   12   0  ...   148   NaN
# 4      1994       近鐵   17   17   6   0  NaN    8    7   0  ...    86   NaN
# 5      1995       道奇   28   28   4   3  NaN   13    6   0  ...    78   2.0
# 6      1996       道奇   33   33   3   2  NaN   16   11   0  ...    85   6.0
# 7      1997       道奇   33   33   1   0  NaN   14   12   0  ...    92   2.0
# 8      1998       道奇   12   12   2   0  NaN    2    7   0  ...    38   0.0
# 9      1998      大都會   17   16   1   0  NaN    4    5   0  ...    56   2.0
# 10     '98計      大都會   29   28   3   0  NaN    6   12   0  ...    94   2.0
# ...

# %% [markdown]
# ### <><<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %% [markdown]
# ## How to learn AI and your direction
# ![how_to_learn](topic.PNG)

# %% [markdown]
# ### scikit-learn has been done

# %% [markdown]
# ## fake data and overfitting

# %%
x=np.random.rand(6,2)

# %%
x
# Out:
# array([[0.81062034, 0.00903294],
#        [0.34154837, 0.0971012 ],
#        [0.83556083, 0.61116691],
#        [0.47581997, 0.95721486],
#        [0.08368573, 0.28954001],
#        [0.89158466, 0.40520056]])

# %%
plt.scatter(x[:,0],x[:,1],c='r',s=50)

# %%
def my_fun(n=1):
    plt.scatter(x[:,0],x[:,1],c='r',s=50)
    t=np.linspace(0,1,1000)
    plt.plot(t,np.sin(n*t))

# %%
my_fun()

# %%
from ipywidgets import interact

# %%
interact(my_fun,n=(1,200))
# Out:
# interactive(children=(IntSlider(value=1, description='n', max=200, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.my_fun(n=1)>

# %% [markdown]
# ## imitate
# $ f(x)=1.2x+0.8+\epsilon $

# %%
x=np.linspace(0,5,200)
y=1.2*x+0.8+0.5*np.random.rand(200)

# %%
plt.scatter(x,y)

# %% [markdown]
# ## 分資料訓練和測試

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 數據分析喜歡的形式
# $$[x_{1},x_{2},....]$$
# ### 轉成這種
# $$[[x_{1}],[x_{2}]]$$

# %%
x=x.reshape(200,1)

# %%
y=y.reshape(200,1)

# %% [markdown]
# x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,ran)
